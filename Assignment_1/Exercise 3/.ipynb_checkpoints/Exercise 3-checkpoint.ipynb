# %%
from data_generator import generate_losangles, generate_edges
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from tail_scratch_nn import DNN
import numpy as np

# %%
quadrants = [0,1,2,3]
data_train = []
data_test = []
amount_train = 2000 # Amount of data per class
amount_test = 100

# %%
for quadrant in quadrants:
    data_train.extend(generate_losangles(amount_train,quadrant))
    data_test.extend(generate_losangles(amount_test,quadrant))
    data_train.extend(generate_edges(amount_train,quadrant))
    data_test.extend(generate_edges(amount_test,quadrant))

# %%
data_train = np.array(data_train)
data_test = np.array(data_test)

# %%
X_train = data_train[:,[0,1]]
y_train = data_train[:,2]
x_test = data_test[:,[0,1]]
y_test = data_test[:,2]

# %%
plt.figure(figsize=(10,10))
plt.title('TRAIN SET')
plt.scatter(X_train[:,0], X_train[:,1], c = y_train)

# %%
plt.figure(figsize=(10,10))
plt.title('TEST SET')
plt.scatter(x_test[:,0], x_test[:,1], c = y_test)

# %%
neural_net = DNN()

# %%
neural_net.fit(X_train.reshape(2,-1),y_train.reshape(1,-1),x_test.reshape(2,-1),y_test.reshape(1,-1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-34b179246725> in <module>
# ----> 1 neural_net.fit(X_train.reshape(2,-1),y_train.reshape(1,-1),x_test.reshape(2,-1),y_test.reshape(1,-1))
#
# ~/anaconda3/lib/python3.7/site-packages/tail_scratch_nn/neural_network.py in fit(self, X_train, y_train, hidden, output)
#      38         self.output = output # function passed as argument to be used on output layers
#      39
# ---> 40         if self.output == sigmoid:
#      41             self.output_derivative = sigmoid_derivative
#      42         elif self.output == softmax:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
X_train.reshape(2,-1).shape
# Out:
# (2, 8000)

# %%
y_train.reshape(1,-1).shape
# Out:
# (1, 8000)

# %%
x_test.reshape(2,-1).shape
# Out:
# (2, 800)

# %%
y_test.reshape(1,-1).shape
# Out:
# (1, 800)
